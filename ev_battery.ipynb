# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv("vin93.csv")
data
# Out:
#          terminaltime  soc  speed  totalodometer  chargestatus  totalvoltage  \
# 0                56.0   68   5.00            2.1             3         370.6
# 1            493880.0   68  51.00            4.1             3         362.6
# 2            493890.0   68  50.90            4.3             3         366.1
# 3            493900.0   68  52.30            4.4             3         364.0
# 4            493910.0   67  60.00            4.6             3         363.6
# ...               ...  ...    ...            ...           ...           ...
# 1203508   114215843.0   45  32.85        66296.4             3         345.7
# 1203509   114215853.0   45  15.80        66296.4             3         342.0
# 1203510   114215863.0   45  43.14        66296.5             3         351.2
# 1203511   114215883.0   45   7.76        66296.6             3         350.6
# 1203512   114215913.0   45   3.09        66296.7             3         350.6
#
# ...

# %%
count : int = 0
for i in data["probetemperatures"][0]:
    if i == '~':
        count+=1
print(count)
# Out:
# 31

# %%
data["soc"].value_counts()
# Out:
# soc
# 99     21982
# 88     21182
# 94     20353
# 74     19043
# 96     18649
#        ...
# 6        185
# 3         55
# 1         52
# 2         42
# 127       18
# Name: count, Length: 101, dtype: int64
